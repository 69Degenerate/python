# %%
import pandas as pd

# %%
f = pd.read_csv("https://www.sololearn.com/uploads/ca-covid.csv")

# %%
print(f.tail())
# Out:
#          date       state  cases  deaths
# 337  27.12.20  California  37555      62
# 338  28.12.20  California  41720     246
# 339  29.12.20  California  34166     425
# 340  30.12.20  California  32386     437
# 341  31.12.20  California  32264     574

# %%
print(f.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 342 entries, 0 to 341
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    342 non-null    object
#  1   state   342 non-null    object
#  2   cases   342 non-null    int64
#  3   deaths  342 non-null    int64
# dtypes: int64(2), object(2)
# memory usage: 10.8+ KB
# None

# %%
f.drop('state',axis=1,inplace=True)

# %%
print(f)
# Out:
#          date  cases  deaths
# 0    25.01.20      1       0
# 1    26.01.20      1       0
# 2    27.01.20      0       0
# 3    28.01.20      0       0
# 4    29.01.20      0       0
# ..        ...    ...     ...
# 337  27.12.20  37555      62
# 338  28.12.20  41720     246
# 339  29.12.20  34166     425
# 340  30.12.20  32386     437
# 341  31.12.20  32264     574
#
# [342 rows x 3 columns]

# %%
f['month'] = pd.to_datetime(f['date'], format="%d.%m.%y").dt.month_name()

# %%
print(f.head())
# Out:
#        date  cases  deaths    month
# 0  25.01.20      1       0  January
# 1  26.01.20      1       0  January
# 2  27.01.20      0       0  January
# 3  28.01.20      0       0  January
# 4  29.01.20      0       0  January

# %%
f['month'].value_counts()
# Out:
# March        31
# May          31
# July         31
# August       31
# October      31
# December     31
# April        30
# June         30
# September    30
# November     30
# February     29
# January       7
# Name: month, dtype: int64

# %%
(f.groupby('month')['cases']).sum()
# Out:
# month
# April          41887
# August        210268
# December     1070577
# February          25
# January            3
# July          270120
# June          119039
# March           8555
# May            62644
# November      301944
# October       114123
# September     108584
# Name: cases, dtype: int64

# %%
import matplotlib as plt

# %%
df = pd.read_csv("https://www.sololearn.com/uploads/ca-covid.csv")
df.drop('state', axis=1, inplace=True)
df['date'] = pd.to_datetime(df['date'], format="%d.%m.%y")
df['month'] = df['date'].dt.month
df.set_index('date', inplace=True)

df[df["month"]==6]["cases"].plot(kind="box")
# Out:
# <AxesSubplot: >

# %%
df[df["month"]==6]["cases"].plot(kind="hist")
# Out:
# <AxesSubplot: ylabel='Frequency'>

# %%
df.plot(kind="hist",bins=10)
# Out:
# <AxesSubplot: ylabel='Frequency'>

# %%
df[df["month"]==6][["cases","deaths"]].plot(kind="area", stacked=False)
# Out:
# <AxesSubplot: xlabel='date'>

# %%
df[df["month"]==6][["cases","deaths"]].plot(kind="scatter", x='cases',y='deaths')
# Out:
# <AxesSubplot: xlabel='cases', ylabel='deaths'>

# %%
df.groupby("month")["cases"].sum().plot(kind='pie')
# Out:
# <AxesSubplot: ylabel='cases'>

# %%
data = {

    'sport': ["Soccer", "Tennis", "Soccer", "Hockey"],

    'players': [5, 4, 8, 20]

}

df = pd.DataFrame(data)

df.groupby('sport')['players'].sum().plot(kind="pie")
# Out:
# <AxesSubplot: ylabel='players'>
